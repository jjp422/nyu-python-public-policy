# %% [markdown]
# <a href="https://colab.research.google.com/github/jjp422/nyu-python-public-policy/blob/master/Homework3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', -1)  # or 199

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/My Drive/Data for Python/cleaned_311_data_hw3.csv', header='infer')

# %%
set(df.complaint_type)
# Out:
# {'Bridge Condition',
#  'Broken Parking Meter',
#  'Bus Stop Shelter Complaint',
#  'Graffiti',
#  'Highway Condition',
#  'Maintenance or Facility',
#  'Public Payphone Complaint',
#  'Public Toilet',
#  'School Maintenance'}

# %%
set(df.descriptor) #Despite the hw prompt, I don't see any null/NA values here--am I missing something?
# Out:
# {'Air Conditioning Problem',
#  'American Flag',
#  'Asbestos',
#  'Bent/Loose',
#  'Broken Fence',
#  'Broken Glass',
#  'Broken Lock',
#  'Broken Water Fountain',
#  'Broken Window',
#  'Cave-in',
#  'Coin or Card Did Not Register',
#  'Concrete Barrier',
#  'Crash Cushion Defect',
#  'Credit Card Stuck in Meter',
#  'Damaged Bench',
#  'Damaged Leg or Pole Bent',
#  'Damaged Other',
#  'Damaged Telephone',
#  'Damaged Toilet/Sink',
#  'Damaged or Leaking Roof',
#  'Damaged or Missing Ad Box',
#  'Dead Animal',
#  'Decorative Necklace Lighting',
#  'Dirt, Debris, Litter Complaint',
#  'Dirty/Graffiti',
#  'Fallen Debris from Bridge',
#  'Fence',
#  'Flooded',
#  'Garbage or Litter',
#  'Graffiti',
#  'Graffiti - Bridge',
#  'Graffiti - Highway',
#  'Graffiti or Vandalism',
#  'Graffiti/Litter on Phone',
#  'Grass/Weeds',
#  'Guard Rail - Bridge',
#  'Guard Rail - Highway',
#  'Heating Problem',
#  'High Grass',
#  'Highway Fence',
#  'Hours of Operation',
#  'Lack of Supplies',
#  'Leaky Roof',
#  'Lighting',
#  'Litter',
#  'Loose Plate',
#  'Lost Coin',
#  'Missing/Stump',
#  'New Automatic Public Toilet Request',
#  'No Dial Tone',
#  'No Receipt',
#  'Other School Condition',
#  'Out of Order',
#  'Painted Line/Marking',
#  'Parking Card Stuck in Meter',
#  'Phone Blocking Sidewalk',
#  'Plumbing Problem',
#  'Poison Ivy',
#  'Police Report Not Requested',
#  'Police Report Requested',
#  'Pothole',
#  'Pothole - Highway',
#  'Relocation of Parking Meter',
#  'Rodent Sighting',
#  'Rodents/Mice',
#  'Rough Pavement',
#  'Sign Blocked by Tree',
#  'Sign Missing or Defective',
#  'Snow Removal Requested',
#  'Snow on Overpass',
#  'Snow or Ice',
#  'Snow/Ice',
#  'Structure - Indoors',
#  'Structure - Outdoors',
#  'Timer Defect - Fast/Fail',
#  'Unclean Condition',
#  'Unsafe Worksite',
#  'Unsecured Facility'}

# %%
df['descriptor'] = df['descriptor'].str.lower()
df['complaint_type'] = df['complaint_type'].str.lower()

# %%
grafitti_counts = df.groupby(['complaint_type','descriptor']).size().reset_index(name='count_of_311_requests').sort_values('count_of_311_requests', ascending=False)

# %%
graffiti_counts
# Out:
#                 complaint_type                           descriptor  \
# 30  graffiti                    graffiti
# 55  maintenance or facility     structure - outdoors
# 15  broken parking meter        no receipt
# 11  broken parking meter        coin or card did not register
# 16  broken parking meter        out of order
# 48  maintenance or facility     garbage or litter
# 50  maintenance or facility     grass/weeds
# 44  highway condition           pothole - highway
# 54  maintenance or facility     structure - indoors
# 52  maintenance or facility     rodent sighting
# 51  maintenance or facility     hours of operation
# 67  school maintenance          air conditioning problem
# 19  broken parking meter        timer defect - fast/fail
# 49  maintenance or facility     graffiti or vandalism
# 41  highway condition           litter
# 56  maintenance or facility     unsecured facility
# 77  school maintenance          other school condition
# 20  bus stop shelter complaint  broken glass
# 12  broken parking meter        credit card stuck in meter
# 82  school maintenance          unclean condition
# 80  school maintenance          rodents/mice
# 37  highway condition           graffiti - highway
# 36  highway condition           dead animal
# 74  school maintenance          heating problem
# 33  highway condition           cave-in
# 47  maintenance or facility     broken glass
# 57  public payphone complaint   damaged telephone
# 26  bus stop shelter complaint  dirty/graffiti
# 43  highway condition           painted line/marking
# 31  graffiti                    police report not requested
# 53  maintenance or facility     snow or ice
# 39  highway condition           high grass
# 27  bus stop shelter complaint  lighting
# 17  broken parking meter        parking card stuck in meter
# 7   bridge condition            pothole
# 14  broken parking meter        missing/stump
# 58  public payphone complaint   graffiti/litter on phone
# 32  graffiti                    police report requested
# 25  bus stop shelter complaint  damaged other
# 28  bus stop shelter complaint  sign missing or defective
# 42  highway condition           loose plate
# 13  broken parking meter        graffiti
# 78  school maintenance          plumbing problem
# 46  highway condition           unsafe worksite
# 2   bridge condition            dirt, debris, litter complaint
# 10  broken parking meter        bent/loose
# 40  highway condition           highway fence
# 5   bridge condition            graffiti - bridge
# 73  school maintenance          graffiti
# 8   bridge condition            rough pavement
# 35  highway condition           crash cushion defect
# 61  public payphone complaint   phone blocking sidewalk
# 71  school maintenance          broken water fountain
# 60  public payphone complaint   no dial tone
# 3   bridge condition            fallen debris from bridge
# 24  bus stop shelter complaint  damaged or missing ad box
# 21  bus stop shelter complaint  damaged bench
# 6   bridge condition            guard rail - bridge
# 76  school maintenance          leaky roof
# 75  school maintenance          lack of supplies
# 4   bridge condition            fence
# 45  highway condition           sign blocked by tree
# 29  bus stop shelter complaint  snow removal requested
# 9   bridge condition            snow on overpass
# 66  public toilet               new automatic public toilet request
# 68  school maintenance          asbestos
# 81  school maintenance          snow/ice
# 22  bus stop shelter complaint  damaged leg or pole bent
# 64  public toilet               dirty/graffiti
# 69  school maintenance          broken fence
# 70  school maintenance          broken lock
# 18  broken parking meter        relocation of parking meter
# 65  public toilet               flooded
# 38  highway condition           guard rail - highway
# 72  school maintenance          broken window
# 59  public payphone complaint   lost coin
# 0   bridge condition            american flag
# 62  public toilet               damaged other
# 1   bridge condition            decorative necklace lighting
# 79  school maintenance          poison ivy
# 63  public toilet               damaged toilet/sink
# 23  bus stop shelter complaint  damaged or leaking roof
# 34  highway condition           concrete barrier
#
#     count_of_311_requests graffiti_flag
# 30  24707                  True
# 55  7830                   False
# 15  5206                   False
# 11  3833                   False
# 16  3787                   False
# 48  3500                   False
# 50  2084                   False
# 44  1505                   False
# 54  1276                   False
# 52  792                    False
# 51  697                    False
# 67  647                    False
# 19  594                    False
# 49  577                    True
# 41  572                    False
# 56  550                    False
# 77  527                    False
# 20  391                    False
# 12  373                    False
# 82  364                    False
# 80  330                    False
# 37  310                    True
# 36  300                    False
# 74  258                    False
# 33  236                    False
# 47  210                    False
# 57  201                    False
# 26  187                    True
# 43  184                    False
# 31  168                    True
# 53  149                    False
# 39  147                    False
# 27  140                    False
# 17  139                    False
# 7   134                    False
# 14  122                    False
# 58  112                    True
# 32  111                    True
# 25  109                    False
# 28  93                     False
# 42  89                     False
# 13  83                     True
# 78  80                     False
# 46  76                     False
# 2   74                     False
# 10  64                     False
# 40  61                     False
# 5   60                     True
# 73  46                     True
# 8   40                     False
# 35  38                     False
# 61  32                     False
# 71  28                     False
# 60  27                     False
# 3   23                     False
# 24  22                     False
# 21  21                     False
# 6   20                     False
# 76  19                     False
# 75  17                     False
# 4   17                     False
# 45  16                     False
# 29  14                     False
# 9   13                     False
# 66  13                     False
# 68  13                     False
# 81  11                     False
# 22  11                     False
# 64  10                     True
# 69  10                     False
# 70  10                     False
# 18  9                      False
# 65  9                      False
# 38  8                      False
# 72  7                      False
# 59  6                      False
# 0   6                      False
# 62  5                      False
# 1   5                      False
# 79  5                      False
# 63  4                      False
# 23  2                      False
# 34  1                      False

# %%
def graffiti_complaint(row):
  if 'graffiti' in row.complaint_type:
    return 'True' 
  elif 'graffiti' in row.descriptor:
    return 'True' 
  else:
    return 'False'

# %%
type(graffiti_complaint)
# Out:
# function

# %%
graffiti_counts['graffiti_flag'] = graffiti_counts.apply(graffiti_complaint, axis=1)

# %%
graffiti_counts
# Out:
#                 complaint_type                           descriptor  \
# 30  graffiti                    graffiti
# 55  maintenance or facility     structure - outdoors
# 15  broken parking meter        no receipt
# 11  broken parking meter        coin or card did not register
# 16  broken parking meter        out of order
# 48  maintenance or facility     garbage or litter
# 50  maintenance or facility     grass/weeds
# 44  highway condition           pothole - highway
# 54  maintenance or facility     structure - indoors
# 52  maintenance or facility     rodent sighting
# 51  maintenance or facility     hours of operation
# 67  school maintenance          air conditioning problem
# 19  broken parking meter        timer defect - fast/fail
# 49  maintenance or facility     graffiti or vandalism
# 41  highway condition           litter
# 56  maintenance or facility     unsecured facility
# 77  school maintenance          other school condition
# 20  bus stop shelter complaint  broken glass
# 12  broken parking meter        credit card stuck in meter
# 82  school maintenance          unclean condition
# 80  school maintenance          rodents/mice
# 37  highway condition           graffiti - highway
# 36  highway condition           dead animal
# 74  school maintenance          heating problem
# 33  highway condition           cave-in
# 47  maintenance or facility     broken glass
# 57  public payphone complaint   damaged telephone
# 26  bus stop shelter complaint  dirty/graffiti
# 43  highway condition           painted line/marking
# 31  graffiti                    police report not requested
# 53  maintenance or facility     snow or ice
# 39  highway condition           high grass
# 27  bus stop shelter complaint  lighting
# 17  broken parking meter        parking card stuck in meter
# 7   bridge condition            pothole
# 14  broken parking meter        missing/stump
# 58  public payphone complaint   graffiti/litter on phone
# 32  graffiti                    police report requested
# 25  bus stop shelter complaint  damaged other
# 28  bus stop shelter complaint  sign missing or defective
# 42  highway condition           loose plate
# 13  broken parking meter        graffiti
# 78  school maintenance          plumbing problem
# 46  highway condition           unsafe worksite
# 2   bridge condition            dirt, debris, litter complaint
# 10  broken parking meter        bent/loose
# 40  highway condition           highway fence
# 5   bridge condition            graffiti - bridge
# 73  school maintenance          graffiti
# 8   bridge condition            rough pavement
# 35  highway condition           crash cushion defect
# 61  public payphone complaint   phone blocking sidewalk
# 71  school maintenance          broken water fountain
# 60  public payphone complaint   no dial tone
# 3   bridge condition            fallen debris from bridge
# 24  bus stop shelter complaint  damaged or missing ad box
# 21  bus stop shelter complaint  damaged bench
# 6   bridge condition            guard rail - bridge
# 76  school maintenance          leaky roof
# 75  school maintenance          lack of supplies
# 4   bridge condition            fence
# 45  highway condition           sign blocked by tree
# 29  bus stop shelter complaint  snow removal requested
# 9   bridge condition            snow on overpass
# 66  public toilet               new automatic public toilet request
# 68  school maintenance          asbestos
# 81  school maintenance          snow/ice
# 22  bus stop shelter complaint  damaged leg or pole bent
# 64  public toilet               dirty/graffiti
# 69  school maintenance          broken fence
# 70  school maintenance          broken lock
# 18  broken parking meter        relocation of parking meter
# 65  public toilet               flooded
# 38  highway condition           guard rail - highway
# 72  school maintenance          broken window
# 59  public payphone complaint   lost coin
# 0   bridge condition            american flag
# 62  public toilet               damaged other
# 1   bridge condition            decorative necklace lighting
# 79  school maintenance          poison ivy
# 63  public toilet               damaged toilet/sink
# 23  bus stop shelter complaint  damaged or leaking roof
# 34  highway condition           concrete barrier
#
#     count_of_311_requests graffiti_flag
# 30  24707                  True
# 55  7830                   False
# 15  5206                   False
# 11  3833                   False
# 16  3787                   False
# 48  3500                   False
# 50  2084                   False
# 44  1505                   False
# 54  1276                   False
# 52  792                    False
# 51  697                    False
# 67  647                    False
# 19  594                    False
# 49  577                    True
# 41  572                    False
# 56  550                    False
# 77  527                    False
# 20  391                    False
# 12  373                    False
# 82  364                    False
# 80  330                    False
# 37  310                    True
# 36  300                    False
# 74  258                    False
# 33  236                    False
# 47  210                    False
# 57  201                    False
# 26  187                    True
# 43  184                    False
# 31  168                    True
# 53  149                    False
# 39  147                    False
# 27  140                    False
# 17  139                    False
# 7   134                    False
# 14  122                    False
# 58  112                    True
# 32  111                    True
# 25  109                    False
# 28  93                     False
# 42  89                     False
# 13  83                     True
# 78  80                     False
# 46  76                     False
# 2   74                     False
# 10  64                     False
# 40  61                     False
# 5   60                     True
# 73  46                     True
# 8   40                     False
# 35  38                     False
# 61  32                     False
# 71  28                     False
# 60  27                     False
# 3   23                     False
# 24  22                     False
# 21  21                     False
# 6   20                     False
# 76  19                     False
# 75  17                     False
# 4   17                     False
# 45  16                     False
# 29  14                     False
# 9   13                     False
# 66  13                     False
# 68  13                     False
# 81  11                     False
# 22  11                     False
# 64  10                     True
# 69  10                     False
# 70  10                     False
# 18  9                      False
# 65  9                      False
# 38  8                      False
# 72  7                      False
# 59  6                      False
# 0   6                      False
# 62  5                      False
# 1   5                      False
# 79  5                      False
# 63  4                      False
# 23  2                      False
# 34  1                      False

# %%
df_graffiti = graffiti_flag
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-173-1236e9c05bcf> in <module>()
# ----> 1 df_graffiti = df.graffiti_flag
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'graffiti_flag'
